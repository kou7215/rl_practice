# %% [markdown]
# # 3x3の迷路ゲームの強化学習

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 進める方向は1, 壁があるならnp.nanとする
# 行がs0 ~ s7. s8はゴールなので方策を定義しない.
# 列は移動する四方向.

# %%
theta_0 = np.array([[np.nan, 1, 1, np.nan],
                    [np.nan, 1, np.nan, 1],
                    [np.nan, np.nan, 1, 1],
                    [1, 1, 1, np.nan],
                    [np.nan, np.nan, 1, 1],
                    [1, np.nan, np.nan, np.nan],
                    [1, np.nan, np.nan, np.nan],
                    [1, 1, np.nan, np.nan]])

# %%
theta_0
# Out:
# array([[nan,  1.,  1., nan],
#        [nan,  1., nan,  1.],
#        [nan, nan,  1.,  1.],
#        [ 1.,  1.,  1., nan],
#        [nan, nan,  1.,  1.],
#        [ 1., nan, nan, nan],
#        [ 1., nan, nan, nan],
#        [ 1.,  1., nan, nan]])

# %%
theta_0.shape
# Out:
# (8, 4)

# %%
def simple_convert_into_pi_from_theta(theta):
    '''
        単純に割合を計算する
    '''
    [m, n] = theta.shape
    pi = np.zeros((m, n))
    for i in range(0, m):
        pi[i, :] = theta[i, :]/np.nansum(theta[i, :])  # nansum : nanは0としてsumをとる.
    pi = np.nan_to_num(pi)  # nan -> 0へ置換.
    return pi

# %% [markdown]
# ## 初期の方策pi_0を求める

# %%
pi_0 = simple_convert_into_pi_from_theta(theta_0)
pi_0
# Out:
# array([[0.        , 0.5       , 0.5       , 0.        ],
#        [0.        , 0.5       , 0.        , 0.5       ],
#        [0.        , 0.        , 0.5       , 0.5       ],
#        [0.33333333, 0.33333333, 0.33333333, 0.        ],
#        [0.        , 0.        , 0.5       , 0.5       ],
#        [1.        , 0.        , 0.        , 0.        ],
#        [1.        , 0.        , 0.        , 0.        ],
#        [0.5       , 0.5       , 0.        , 0.        ]])

# %% [markdown]
# ## 1step移動後の状態sを求める

# %%
def get_next_s(pi, s):
    direction = ['up', 'right', 'down', 'left']
    next_direction = np.random.choice(direction, p=pi[s, :])
    
    if next_direction == 'up':
        s_next = s - 3
    elif next_direction == 'right':
        s_next = s + 1
    elif next_direction == 'down':
        s_next = s + 3
    else:
        s_next = s - 1
    return s_next

# %% [markdown]
# ## エージェントが迷路をゴールするまで永遠に移動させる関数の定義

# %%
def goal_maze(pi):
    s = 0 # スタート地点
    state_history = [0] # エージェントの移動を記録するリスト.
    
    while(1):
        next_s = get_next_s(pi, s)
        state_history.append(next_s)
        
        if next_s == 8:  # goal
            break
        else:
            s = next_s
    return state_history

# %%
state_history = goal_maze(pi_0)
state_history
# Out:
# [0,
#  3,
#  6,
#  3,
#  0,
#  1,
#  0,
#  3,
#  0,
#  1,
#  0,
#  1,
#  2,
#  5,
#  2,
#  1,
#  2,
#  1,
#  0,
#  1,
#  0,
#  3,
#  4,
#  3,
#  4,
#  7,
#  8]

# %% [markdown]
# ## ゴール到達までのstep数

# %%
len(state_history) - 1
# Out:
# 26

# %% [markdown]
# ## 方策勾配法に従ってエージェントを動かす

# %%
def softmax_convert_into_pi_from_theta(theta):
    beta = 1.0
    [m, n] = theta.shape
    pi = np.zeros((m, n))
    
    exp_theta = np.exp(beta * theta)
    for i in range(0, m):
        pi[i, :] = exp_theta[i, :] / np.nansum(exp_theta[i, :])  # 各sに対してsoftmaxから得られる確率値を与える.
    
    pi = np.nan_to_num(pi)
    
    return pi

# %%
pi_0 = softmax_convert_into_pi_from_theta(theta_0)
pi_0
# Out:
# array([[0.        , 0.5       , 0.5       , 0.        ],
#        [0.        , 0.5       , 0.        , 0.5       ],
#        [0.        , 0.        , 0.5       , 0.5       ],
#        [0.33333333, 0.33333333, 0.33333333, 0.        ],
#        [0.        , 0.        , 0.5       , 0.5       ],
#        [1.        , 0.        , 0.        , 0.        ],
#        [1.        , 0.        , 0.        , 0.        ],
#        [0.5       , 0.5       , 0.        , 0.        ]])

# %% [markdown]
# ## 行動aした際のnext stateを返す

# %%
def get_action_and_next_s(pi, s):
    direction = ['up', 'right', 'down', 'left']
    next_direction = np.random.choice(direction, p=pi[s, :])
    
    if next_direction == 'up':
        action = 0
        s_next = s - 3
    elif next_direction == 'right':
        action = 1
        s_next = s + 1
    elif next_direction == 'down':
        action = 2
        s_next = s + 3
    else:
        action = 3
        s_next = s - 1
    return [action, s_next]

# %% [markdown]
# ## 迷路を解く関数の定義、状態と行動の履歴を出力

# %%
# [s0, action0]
# [s1, action1]
# [s2, action2]
#     :
#     :
# [s8, actionN]

def goal_maze_ret_s_a(pi):
    s = 0
    s_a_history = [[0, np.nan]]  # [current_state, previous_action]
    
    while(1):
        [action, next_s] = get_action_and_next_s(pi, s)
        s_a_history[-1][1] = action  # 最新の履歴にnext_actionを刻む
        
        s_a_history.append([next_s, np.nan])  # 
        
        if next_s == 8:  # goal
            break
        else:
            s = next_s
    return s_a_history

# %%
s_a_history = goal_maze_ret_s_a(pi_0)
s_a_history
# Out:
# [[0, 2],
#  [3, 2],
#  [6, 0],
#  [3, 1],
#  [4, 3],
#  [3, 1],
#  [4, 3],
#  [3, 0],
#  [0, 1],
#  [1, 3],
#  [0, 2],
#  [3, 0],
#  [0, 2],
#  [3, 1],
#  [4, 3],
#  [3, 1],
#  [4, 3],
#  [3, 0],
#  [0, 2],
#  [3, 0],
#  [0, 1],
#  [1, 3],
#  [0, 2],
#  [3, 0],
#  [0, 2],
#  [3, 2],
#  [6, 0],
#  [3, 1],
#  [4, 2],
#  [7, 0],
#  [4, 2],
#  [7, 1],
#  [8, nan]]

# %% [markdown]
# ## 方策勾配法に基づいて方策を更新する

# %%
def update_theta(theta, pi, s_a_history):
    eta = 0.1
    T = len(s_a_history) - 1  # ゴールまでの総ステップ数
    
    [m, n] = theta.shape
    delta_theta = theta.copy()
    
    for i in range(m):  # i : sに関するidx
        for j in range(n):   # j : actionに関するidx
            if not np.isnan(theta[i, j]):
                # 履歴から状態iのものを取り出す
                SA_i = [SA for SA in s_a_history if SA[0] == i]
                # 状態iで行動jをしたものを取り出す
                SA_ij = [SA for SA in s_a_history if SA == [i, j]]
                # 一致しなかったら空リスト
                #print('i:', i, ' j:', j)
                #print('SA_i : ', SA_i)
                #print('SA_ij : ', SA_ij)
                #print()
                
                N_i = len(SA_i)  # 状態i(s∍i)で行動した総回数
                N_ij = len(SA_ij)  # 状態i(s∍i)で行動jをとった回数
                delta_theta[i, j] = (N_ij - pi[i, j] * N_i) / T  # NOTE ここを起点に読むとよい
    new_theta = theta + eta * delta_theta
    
    return new_theta

# %%
new_theta = update_theta(theta_0, pi_0, s_a_history)
pi = softmax_convert_into_pi_from_theta(new_theta)
pi
# Out:
# array([[0.        , 0.49687504, 0.50312496, 0.        ],
#        [0.        , 0.49843751, 0.        , 0.50156249],
#        [0.        , 0.        , 0.5       , 0.5       ],
#        [0.33437337, 0.33437337, 0.33125327, 0.        ],
#        [0.        , 0.        , 0.49843751, 0.50156249],
#        [1.        , 0.        , 0.        , 0.        ],
#        [1.        , 0.        , 0.        , 0.        ],
#        [0.5       , 0.5       , 0.        , 0.        ]])

# %% [markdown]
# ## 方策勾配法で迷路を解く

# %%
stop_eps = 10**-4
losses = []
theta = theta_0
pi = pi_0
is_continue = True
count = 1
while is_continue:
    # 現在の方策piに従って移動. 履歴を取得.
    s_a_history = goal_maze_ret_s_a(pi)
    # 方策勾配法に従ってthetaの更新.
    new_theta = update_theta(theta, pi, s_a_history)
    # 更新後のthetaから新しい方策piへとsoftmaxで変換する.
    new_pi = softmax_convert_into_pi_from_theta(new_theta)
    
    loss = np.sum(np.abs(new_pi - pi))
    losses.append(loss)
    
    #print(loss)
    #print('total step at the end of episode : ', len(s_a_history) - 1)
    
    if loss < stop_eps:
        is_continue = False
    else:
        theta = new_theta
        pi = new_pi
        
print(loss)
print('total step at the end of episode : ', len(s_a_history) - 1)
# Out:
# 0.008100555018371258
# total step at the end of episode :  24
# 0.008760883410009135
# total step at the end of episode :  90
# 0.024260481707974513
# total step at the end of episode :  8
# 0.0056458036826234625
# total step at the end of episode :  128
# 0.0063050844897292735
# total step at the end of episode :  120
# 0.024350979148419827
# total step at the end of episode :  8
# 0.01488159750224577
# total step at the end of episode :  44
# 0.048300487435825934
# total step at the end of episode :  4
# 0.01502195776001597
# total step at the end of episode :  16
# 0.01908910958635246
# total step at the end of episode :  18
# 0.010418528587787135
# total step at the end of episode :  30
# 0.010255053132740666
# total step at the end of episode :  48
# 0.0319528476781305
# total step at the end of episode :  6
# 0.011281917200344549
# total step at the end of episode :  38
# 0.011603564651186227
# total step at the end of episode :  30
# 0.03203764528919206
# total step at the end of episode :  6
# 0.011805849176340477
# total step at the end of episode :  18
# 0.01922009973138178
# total step at the end of episode :  14
# 0.014679992189553737
# total step at the end of episode :  24
# 0.019847089751168556
# total step at the end of episode :  20
# 0.01274905524973835
# total step at the end of episode :  48
# 0.015362206889337815
# total step at the end of episode :  28
# 0.02048732421709809
# total step at the end of episode :  14
# 0.007940312869504862
# total step at the end of episode :  54
# 0.012722403619298162
# total step at the end of episode :  66
# 0.009157126989812026
# total step at the end of episode :  46
# 0.028384956667378503
# total step at the end of episode :  10
# 0.00912916137938502
# total step at the end of episode :  40
# 0.009933153015943719
# total step at the end of episode :  70
# 0.01210544544072134
# total step at the end of episode :  34
# 0.009530732545485254
# total step at the end of episode :  140
# 0.007386192114062717
# total step at the end of episode :  146
# 0.015472659598617433
# total step at the end of episode :  36
# 0.03123804451602591
# total step at the end of episode :  6
# 0.02385328460378905
# total step at the end of episode :  16
# 0.008156542188797578
# total step at the end of episode :  84
# 0.03827428800007898
# total step at the end of episode :  6
# 0.014910654988305794
# total step at the end of episode :  24
# 0.013912073331296793
# total step at the end of episode :  36
# 0.04586750996813299
# total step at the end of episode :  4
# 0.01160207854458728
# total step at the end of episode :  82
# 0.032499835929627297
# total step at the end of episode :  6
# 0.014773293471226467
# total step at the end of episode :  70
# 0.010163413248434672
# total step at the end of episode :  38
# 0.009689183141851243
# total step at the end of episode :  66
# 0.027030426804338648
# total step at the end of episode :  10
# 0.01768120589633121
# total step at the end of episode :  20
# 0.013105597334237273
# total step at the end of episode :  20
# 0.011323965644497058
# total step at the end of episode :  26
# 0.015594687392997741
# total step at the end of episode :  16
# 0.01891984033021865
# total step at the end of episode :  20
# 0.016957477645546615
# total step at the end of episode :  18
# 0.029469253112861193
# total step at the end of episode :  12
# 0.009601816035356758
# total step at the end of episode :  28
# 0.008036093793845789
# total step at the end of episode :  150
# 0.016368095152553108
# total step at the end of episode :  32
# 0.009347550893421375
# total step at the end of episode :  74
# 0.017972894368848302
# total step at the end of episode :  10
# 0.017182936271122218
# total step at the end of episode :  22
# 0.017126412193497365
# total step at the end of episode :  48
# 0.011471493132089616
# total step at the end of episode :  102
# 0.04477561566388044
# total step at the end of episode :  4
# 0.01259934972329596
# total step at the end of episode :  82
# 0.044245408552293475
# total step at the end of episode :  4
# 0.013460566964254794
# total step at the end of episode :  16
# 0.008592953568528627
# total step at the end of episode :  68
# 0.018125158421463283
# total step at the end of episode :  32
# 0.01976120908242701
# total step at the end of episode :  32
# 0.016525300243142804
# total step at the end of episode :  18
# 0.0162443548654726
# total step at the end of episode :  16
# 0.011507445874199995
# total step at the end of episode :  16
# 0.006162154154399246
# total step at the end of episode :  108
# 0.02109612483913681
# total step at the end of episode :  8
# 0.03489143565129471
# total step at the end of episode :  20
# 0.021065054057885113
# total step at the end of episode :  20
# 0.012227598369118187
# total step at the end of episode :  26
# 0.0255549882211501
# total step at the end of episode :  8
# 0.014079410618174137
# total step at the end of episode :  20
# 0.043447618456858406
# total step at the end of episode :  4
# 0.023028204453856227
# total step at the end of episode :  14
# 0.020026179318870463
# total step at the end of episode :  10
# 0.025201862254824403
# total step at the end of episode :  12
# 0.04275992422859681
# total step at the end of episode :  4
# 0.019324701193016602
# total step at the end of episode :  12
# 0.04211133881903145
# total step at the end of episode :  4
# 0.010892759072768154
# total step at the end of episode :  32
# 0.02468042865428466
# total step at the end of episode :  8
# 0.010884806885742893
# total step at the end of episode :  22
# 0.007696346318470215
# total step at the end of episode :  22
# 0.041421212657923756
# total step at the end of episode :  4
# 0.029537417923397202
# total step at the end of episode :  10
# 0.018223271650514627
# total step at the end of episode :  20
# 0.017409288741089213
# total step at the end of episode :  24
# 0.04051375426798609
# total step at the end of episode :  4
# 0.024216544897358916
# total step at the end of episode :  10
# 0.008682275685759466
# total step at the end of episode :  18
# 0.01140419714547275
# total step at the end of episode :  28
# 0.015154024360999385
# total step at the end of episode :  24
# 0.030395398077971703
# total step at the end of episode :  6
# 0.009613519957277161
# total step at the end of episode :  32
# 0.025121794935225428
# total step at the end of episode :  6
# 0.01657553494551256
# total step at the end of episode :  18
# 0.024269639340794236
# total step at the end of episode :  10
# 0.017367221231563923
# total step at the end of episode :  18
# 0.01154415328378755
# total step at the end of episode :  46
# 0.011746806307005198
# total step at the end of episode :  16
# 0.020594547104338057
# total step at the end of episode :  12
# 0.023221230324247444
# total step at the end of episode :  48
# 0.013343025142420917
# total step at the end of episode :  46
# 0.012885238187611725
# total step at the end of episode :  22
# 0.024847683666997855
# total step at the end of episode :  6
# 0.01122945458594321
# total step at the end of episode :  24
# 0.032004327104953045
# total step at the end of episode :  8
# 0.009206247456346905
# total step at the end of episode :  38
# 0.017725406695476564
# total step at the end of episode :  52
# 0.016159426982051805
# total step at the end of episode :  10
# 0.01696260349637585
# total step at the end of episode :  12
# 0.02241543449925376
# total step at the end of episode :  8
# 0.017400635951718424
# total step at the end of episode :  64
# 0.022736629322928303
# total step at the end of episode :  8
# 0.013301027209357552
# total step at the end of episode :  16
# 0.022655210504526457
# total step at the end of episode :  8
# 0.027105007809020032
# total step at the end of episode :  6
# 0.0128033434415884
# total step at the end of episode :  14
# 0.01579410808821563
# total step at the end of episode :  50
# 0.037938022664477766
# total step at the end of episode :  4
# 0.022271342301034003
# total step at the end of episode :  14
# 0.009918758343507361
# total step at the end of episode :  14
# 0.019097647728588185
# total step at the end of episode :  16
# 0.03727491773774261
# total step at the end of episode :  4
# 0.009376093466698487
# total step at the end of episode :  30
# 0.01067448477058136
# total step at the end of episode :  10
# 0.016927239974527164
# total step at the end of episode :  46
# 0.03681418470458486
# total step at the end of episode :  4
# 0.01894118784395682
# total step at the end of episode :  20
# 0.01503769374181152
# total step at the end of episode :  16
# 0.03634980475779148
# total step at the end of episode :  4
# 0.01643368618947183
# total step at the end of episode :  16
# 0.017074358005203405
# total step at the end of episode :  22
# 0.021881767780879358
# total step at the end of episode :  6
# 0.017729922741568427
# total step at the end of episode :  8
# 0.01764951479726859
# total step at the end of episode :  8
# 0.021327952301208875
# total step at the end of episode :  6
# 0.02345331947802498
# total step at the end of episode :  10
# 0.021032248791862718
# total step at the end of episode :  6
# 0.010274158547171397
# total step at the end of episode :  14
# 0.008647655713084457
# total step at the end of episode :  12
# 0.005306066802545639
# total step at the end of episode :  14
# 0.016450116527044756
# total step at the end of episode :  8
# 0.010170192107406661
# total step at the end of episode :  14
# 0.020758572845498924
# total step at the end of episode :  6
# 0.016836674635964416
# total step at the end of episode :  26
# 0.008896039135048384
# total step at the end of episode :  30
# 0.03437224053881058
# total step at the end of episode :  4
# 0.010132337908921346
# total step at the end of episode :  34
# 0.01241491452097121
# total step at the end of episode :  14
# 0.03395267300750132
# total step at the end of episode :  4
# 0.01825025512299633
# total step at the end of episode :  12
# 0.016805070747254958
# total step at the end of episode :  32
# 0.015977896410106995
# total step at the end of episode :  16
# 0.019242965353745256
# total step at the end of episode :  14
# 0.033630663646119247
# total step at the end of episode :  4
# 0.03313974664005695
# total step at the end of episode :  4
# 0.009517386869354688
# total step at the end of episode :  22
# 0.018647143040423392
# total step at the end of episode :  22
# 0.019806127024080356
# total step at the end of episode :  6
# 0.02203709740898452
# total step at the end of episode :  10
# 0.014002414837133742
# total step at the end of episode :  50
# 0.016942779225791016
# total step at the end of episode :  24
# 0.013535646118231631
# total step at the end of episode :  24
# 0.031093931806271652
# total step at the end of episode :  10
# 0.0086522694747182
# total step at the end of episode :  10
# 0.03261200026661537
# total step at the end of episode :  4
# 0.029181072426453097
# total step at the end of episode :  6
# 0.022385680452830126
# total step at the end of episode :  20
# 0.017645653081833218
# total step at the end of episode :  22
# 0.020459581240476338
# total step at the end of episode :  10
# 0.012617586742724063
# total step at the end of episode :  10
# 0.024304832436885693
# total step at the end of episode :  6
# 0.012452092161430312
# total step at the end of episode :  28
# 0.03156987765937455
# total step at the end of episode :  4
# 0.009282513892522326
# total step at the end of episode :  14
# 0.023104378098336625
# total step at the end of episode :  26
# 0.019939271537978948
# total step at the end of episode :  10
# 0.01504989052654887
# total step at the end of episode :  12
# 0.018922815328210496
# total step at the end of episode :  6
# 0.013867280570939083
# total step at the end of episode :  20
# 0.027253113312783156
# total step at the end of episode :  6
# 0.015290917118676223
# total step at the end of episode :  14
# 0.01646076738901517
# total step at the end of episode :  34
# 0.020352106086889282
# total step at the end of episode :  10
# 0.024045085889138174
# total step at the end of episode :  8
# 0.014602112428069247
# total step at the end of episode :  16
# 0.014579273251986768
# total step at the end of episode :  30
# 0.018913778026077466
# total step at the end of episode :  22
# 0.01653304431762989
# total step at the end of episode :  28
# 0.014002144975827135
# total step at the end of episode :  10
# 0.03171619680824936
# total step at the end of episode :  10
# 0.014812938823920346
# total step at the end of episode :  10
# 0.019051097534471817
# total step at the end of episode :  40
# 0.006521465951322275
# total step at the end of episode :  16
# 0.017558598803823017
# total step at the end of episode :  8
# 0.02337390281613419
# total step at the end of episode :  6
# 0.01478045422831617
# total step at the end of episode :  14
# 0.023077554324774596
# total step at the end of episode :  6
# 0.02333705016087645
# total step at the end of episode :  16
# 0.0211212299309739
# total step at the end of episode :  12
# 0.019138498793438846
# total step at the end of episode :  8
# 0.01889083879431419
# total step at the end of episode :  8
# 0.012161582544097826
# total step at the end of episode :  10
# 0.021568481645025783
# total step at the end of episode :  10
# 0.02725987393452317
# total step at the end of episode :  6
# 0.02332758682183736
# total step at the end of episode :  12
# 0.026995791789972134
# total step at the end of episode :  6
# 0.024892775369671716
# total step at the end of episode :  8
# 0.02117129664832898
# total step at the end of episode :  12
# 0.01913481207421322
# total step at the end of episode :  8
# 0.01102671493889576
# total step at the end of episode :  12
# 0.013070888680672327
# total step at the end of episode :  14
# 0.02217494598135064
# total step at the end of episode :  6
# 0.014079085513047401
# total step at the end of episode :  18
# 0.013608997762923208
# total step at the end of episode :  18
# 0.01804853415101179
# total step at the end of episode :  44
# 0.017843636721655565
# total step at the end of episode :  8
# 0.030208700946381672
# total step at the end of episode :  10
# 0.02935315144510736
# total step at the end of episode :  4
# 0.017252360102310516
# total step at the end of episode :  24
# 0.01850303062030237
# total step at the end of episode :  14
# 0.015166873504008721
# total step at the end of episode :  14
# 0.019483872981826328
# total step at the end of episode :  14
# 0.02905159160956211
# total step at the end of episode :  4
# 0.01765502660440138
# total step at the end of episode :  8
# 0.014652622800765819
# total step at the end of episode :  16
# 0.026934195760425078
# total step at the end of episode :  6
# 0.012075480017305157
# total step at the end of episode :  28
# 0.012775834446582701
# total step at the end of episode :  28
# 0.020093494205304374
# total step at the end of episode :  32
# 0.015896457449390305
# total step at the end of episode :  16
# 0.02209917095131897
# total step at the end of episode :  10
# 0.028570772626037994
# total step at the end of episode :  4
# 0.017050154849135524
# total step at the end of episode :  6
# 0.02141680953710659
# total step at the end of episode :  12
# 0.013791059089207719
# total step at the end of episode :  42
# 0.019915107070138993
# total step at the end of episode :  12
# 0.027990398721420034
# total step at the end of episode :  4
# 0.0166233909391921
# total step at the end of episode :  10
# 0.015279831167121616
# total step at the end of episode :  10
# 0.026272386769143424
# total step at the end of episode :  6
# 0.017823021474018486
# total step at the end of episode :  10
# 0.020960600206585966
# total step at the end of episode :  6
# 0.015550881080300005
# total step at the end of episode :  8
# 0.013289869398069587
# total step at the end of episode :  34
# 0.020813265523180552
# total step at the end of episode :  6
# 0.027049972823635887
# total step at the end of episode :  4
# 0.02809839227687405
# total step at the end of episode :  6
# 0.020411447128846516
# total step at the end of episode :  6
# 0.016304949231945004
# total step at the end of episode :  6
# 0.02621658280173278
# total step at the end of episode :  4
# 0.012312241327952639
# total step at the end of episode :  18
# 0.018136661625052425
# total step at the end of episode :  12
# 0.02587163793963368
# total step at the end of episode :  4
# 0.032636650402185385
# total step at the end of episode :  8
# 0.015104151014904532
# total step at the end of episode :  12
# 0.02556624862564852
# total step at the end of episode :  4
# 0.025198317981918295
# total step at the end of episode :  4
# 0.024835475113364286
# total step at the end of episode :  4
# 0.024477720954559162
# total step at the end of episode :  4
# 0.012814342831880515
# total step at the end of episode :  16
# 0.022468426725385265
# total step at the end of episode :  14
# 0.016922101536270107
# total step at the end of episode :  8
# 0.020434931023340652
# total step at the end of episode :  10
# 0.013191963240744342
# total step at the end of episode :  12
# 0.02427509693165386
# total step at the end of episode :  4
# 0.023925464174346767
# total step at the end of episode :  4
# 0.016103006540760884
# total step at the end of episode :  20
# 0.023716614451015333
# total step at the end of episode :  4
# 0.024248328766663135
# total step at the end of episode :  6
# 0.016315368838248523
# total step at the end of episode :  16
# 0.02324516740081009
# total step at the end of episode :  4
# 0.022909887660490486
# total step at the end of episode :  4
# 0.01447586002637219
# total step at the end of episode :  6
# 0.032688763140400506
# total step at the end of episode :  20
# 0.014362385175093417
# total step at the end of episode :  6
# 0.0245425971346582
# total step at the end of episode :  16
# 0.03125791952734103
# total step at the end of episode :  8
# 0.022455297910926764
# total step at the end of episode :  4
# 0.022131818104049128
# total step at the end of episode :  4
# 0.02079796289478794
# total step at the end of episode :  26
# 0.021870236004990384
# total step at the end of episode :  4
# 0.017061302117604038
# total step at the end of episode :  20
# 0.02685789684998474
# total step at the end of episode :  14
# 0.011736861899714096
# total step at the end of episode :  14
# 0.0186288129418527
# total step at the end of episode :  6
# 0.02305784837051239
# total step at the end of episode :  6
# 0.015343539262179712
# total step at the end of episode :  10
# 0.01538469252117769
# total step at the end of episode :  10
# 0.0218641760737584
# total step at the end of episode :  8
# 0.013886971807383242
# total step at the end of episode :  12
# 0.018387983174128042
# total step at the end of episode :  6
# 0.014152486505716377
# total step at the end of episode :  22
# 0.018561640950093022
# total step at the end of episode :  18
# 0.025283848601868802
# total step at the end of episode :  6
# 0.022925662493884835
# total step at the end of episode :  6
# 0.013754785536198605
# total step at the end of episode :  8
# 0.018156982939610572
# total step at the end of episode :  6
# 0.012591833224784299
# total step at the end of episode :  12
# 0.01786313083232957
# total step at the end of episode :  6
# 0.016788772810028635
# total step at the end of episode :  14
# 0.01821040929697071
# total step at the end of episode :  10
# 0.015681642719579725
# total step at the end of episode :  12
# 0.015060116142180169
# total step at the end of episode :  8
# 0.014474935534609906
# total step at the end of episode :  6
# 0.021614845630150675
# total step at the end of episode :  4
# 0.022327230506900525
# total step at the end of episode :  8
# 0.02521152623977188
# total step at the end of episode :  8
# 0.025241528904018318
# total step at the end of episode :  12
# 0.011131346542652604
# total step at the end of episode :  28
# 0.017402362849210262
# total step at the end of episode :  6
# 0.021349736898019694
# total step at the end of episode :  4
# 0.008944096814632069
# total step at the end of episode :  10
# 0.02212125241384763
# total step at the end of episode :  8
# 0.015218877580703755
# total step at the end of episode :  22
# 0.017032135420629063
# total step at the end of episode :  10
# 0.015867785197724915
# total step at the end of episode :  22
# 0.010382275319118978
# total step at the end of episode :  12
# 0.016055357056737746
# total step at the end of episode :  20
# 0.02173268945983889
# total step at the end of episode :  4
# 0.014994265432969861
# total step at the end of episode :  32
# 0.01704410712753837
# total step at the end of episode :  6
# 0.021940739850557917
# total step at the end of episode :  8
# 0.016546453972245717
# total step at the end of episode :  6
# 0.02141687343184412
# total step at the end of episode :  4
# 0.02110432120599326
# total step at the end of episode :  4
# 0.02229794606444449
# total step at the end of episode :  6
# 0.01819558155458878
# total step at the end of episode :  12
# 0.009829859276895364
# total step at the end of episode :  12
# 0.016103931380039488
# total step at the end of episode :  6
# 0.020801925034574203
# total step at the end of episode :  4
# 0.008376325899845521
# total step at the end of episode :  10
# 0.01421548043247886
# total step at the end of episode :  10
# 0.02064151534424724
# total step at the end of episode :  4
# 0.023818810864734863
# total step at the end of episode :  12
# 0.020367288176530773
# total step at the end of episode :  4
# 0.020070557833858055
# total step at the end of episode :  4
# 0.024424957515450957
# total step at the end of episode :  6
# 0.019705639965347854
# total step at the end of episode :  4
# 0.015768791311544905
# total step at the end of episode :  8
# 0.01374641392002482
# total step at the end of episode :  6
# 0.014471165785882256
# total step at the end of episode :  8
# 0.009931267164829088
# total step at the end of episode :  14
# 0.01931330331739367
# total step at the end of episode :  4
# 0.01903464811143918
# total step at the end of episode :  4
# 0.019347407016399032
# total step at the end of episode :  10
# 0.018513724996486153
# total step at the end of episode :  8
# 0.01859450178055916
# total step at the end of episode :  16
# 0.01897150621889926
# total step at the end of episode :  4
# 0.011500990752162044
# total step at the end of episode :  8
# 0.019191934690907575
# total step at the end of episode :  10
# 0.022102326989731996
# total step at the end of episode :  16
# 0.02077019005757963
# total step at the end of episode :  42
# 0.015402833101577501
# total step at the end of episode :  24
# 0.01922394837872185
# total step at the end of episode :  4
# 0.012675435100254817
# total step at the end of episode :  8
# 0.01644943423465678
# total step at the end of episode :  16
# 0.01895703427852094
# total step at the end of episode :  4
# 0.01996576729198546
# total step at the end of episode :  20
# 0.02139111599645871
# total step at the end of episode :  12
# 0.020510018009337494
# total step at the end of episode :  6
# 0.018305918067483662
# total step at the end of episode :  10
# 0.015181245834778478
# total step at the end of episode :  6
# 0.015895191229225003
# total step at the end of episode :  6
# 0.011587975741703394
# total step at the end of episode :  8
# 0.018498436604080182
# total step at the end of episode :  4
# 0.023474762202066707
# total step at the end of episode :  6
# 0.01834929859181561
# total step at the end of episode :  18
# 0.017463437437608698
# total step at the end of episode :  10
# 0.01567096159293535
# total step at the end of episode :  6
# 0.01730967917105325
# total step at the end of episode :  10
# 0.013411847211920902
# total step at the end of episode :  6
# 0.02111944589619419
# total step at the end of episode :  12
# 0.018416742860639046
# total step at the end of episode :  4
# 0.014444502234191497
# total step at the end of episode :  8
# 0.015046276613942228
# total step at the end of episode :  12
# 0.013386483581760533
# total step at the end of episode :  6
# 0.01770467692363034
# total step at the end of episode :  10
# 0.01336180258507541
# total step at the end of episode :  14
# 0.015494156387402952
# total step at the end of episode :  6
# 0.018145616985701385
# total step at the end of episode :  4
# 0.015361489850907684
# total step at the end of episode :  8
# 0.01791388394376936
# total step at the end of episode :  4
# 0.017657596025879546
# total step at the end of episode :  4
# 0.019755733780542045
# total step at the end of episode :  6
# 0.019557755882846722
# total step at the end of episode :  12
# 0.012412997219850203
# total step at the end of episode :  8
# 0.023061810793016085
# total step at the end of episode :  6
# 0.017424080479150728
# total step at the end of episode :  4
# 0.0171751323531579
# total step at the end of episode :  4
# 0.016685399935944506
# total step at the end of episode :  10
# 0.016170486536199652
# total step at the end of episode :  8
# 0.015203324976093835
# total step at the end of episode :  6
# 0.016925690589302128
# total step at the end of episode :  4
# 0.016685168246168308
# total step at the end of episode :  4
# 0.016568492512231275
# total step at the end of episode :  22
# 0.01661887635343892
# total step at the end of episode :  4
# 0.018914526463001125
# total step at the end of episode :  30
# 0.01606382014624505
# total step at the end of episode :  8
# 0.01638139176315792
# total step at the end of episode :  4
# 0.016150165322385335
# total step at the end of episode :  4
# 0.03000202625534179
# total step at the end of episode :  12
# 0.012295425316442482
# total step at the end of episode :  6
# 0.012402712316012143
# total step at the end of episode :  8
# 0.015838966163740892
# total step at the end of episode :  4
# 0.012106587701946309
# total step at the end of episode :  6
# 0.017622265399389853
# total step at the end of episode :  8
# 0.012858198119218317
# total step at the end of episode :  14
# 0.014988855059452244
# total step at the end of episode :  6
# 0.014840461846054698
# total step at the end of episode :  6
# 0.015721221648694883
# total step at the end of episode :  4
# 0.01407826125274772
# total step at the end of episode :  8
# 0.014594357771838345
# total step at the end of episode :  6
# 0.009109554968798977
# total step at the end of episode :  10
# 0.00907612946782338
# total step at the end of episode :  10
# 0.015715600954496894
# total step at the end of episode :  4
# 0.015495326136452547
# total step at the end of episode :  4
# 0.012142684490529979
# total step at the end of episode :  8
# 0.015347395729225777
# total step at the end of episode :  4
# 0.014225890124938814
# total step at the end of episode :  6
# 0.021716700483894902
# total step at the end of episode :  8
# 0.01595075031451816
# total step at the end of episode :  38
# 0.01639265665913979
# total step at the end of episode :  12
# 0.015220777332667482
# total step at the end of episode :  4
# 0.015008838754650616
# total step at the end of episode :  4
# 0.012808861361397111
# total step at the end of episode :  10
# 0.014880319225456184
# total step at the end of episode :  4
# 0.014145510770730826
# total step at the end of episode :  6
# 0.014638553736299575
# total step at the end of episode :  10
# 0.014722261985507842
# total step at the end of episode :  4
# 0.013563316482345572
# total step at the end of episode :  8
# 0.01189170477581837
# total step at the end of episode :  8
# 0.013030127844508438
# total step at the end of episode :  14
# 0.014677807171982096
# total step at the end of episode :  4
# 0.01709164622363482
# total step at the end of episode :  6
# 0.014415576999298185
# total step at the end of episode :  4
# 0.021263830581562837
# total step at the end of episode :  8
# 0.014244687851458479
# total step at the end of episode :  4
# 0.014480082795927746
# total step at the end of episode :  8
# 0.014205260666292296
# total step at the end of episode :  6
# 0.014095262896787628
# total step at the end of episode :  4
# 0.016843310615898263
# total step at the end of episode :  18
# 0.01215846817795789
# total step at the end of episode :  8
# 0.011677656714154439
# total step at the end of episode :  8
# 0.015110301074903049
# total step at the end of episode :  20
# 0.01690541030631966
# total step at the end of episode :  6
# 0.016780781592514102
# total step at the end of episode :  6
# 0.016656046720254072
# total step at the end of episode :  6
# 0.014348750776083843
# total step at the end of episode :  6
# 0.014205557948383282
# total step at the end of episode :  6
# 0.014197559984950703
# total step at the end of episode :  4
# 0.014001613842645005
# total step at the end of episode :  4
# 0.011662521462419487
# total step at the end of episode :  6
# 0.024288353672181434
# total step at the end of episode :  12
# 0.016652461423190393
# total step at the end of episode :  14
# 0.013753750171874302
# total step at the end of episode :  6
# 0.014086975693948539
# total step at the end of episode :  4
# 0.011998392307699321
# total step at the end of episode :  8
# 0.012822025145260332
# total step at the end of episode :  8
# 0.0187803431951951
# total step at the end of episode :  8
# 0.01331679559636173
# total step at the end of episode :  6
# 0.017296317711408396
# total step at the end of episode :  10
# 0.014759780988895535
# total step at the end of episode :  8
# 0.014243651203646956
# total step at the end of episode :  4
# 0.0117452055519255
# total step at the end of episode :  8
# 0.012862300858963657
# total step at the end of episode :  8
# 0.01292794652184219
# total step at the end of episode :  10
# 0.015058686650893785
# total step at the end of episode :  10
# 0.021061002436204124
# total step at the end of episode :  6
# 0.012753700306393181
# total step at the end of episode :  8
# 0.014370152777314724
# total step at the end of episode :  4
# 0.00918303632045843
# total step at the end of episode :  12
# 0.011735027565764153
# total step at the end of episode :  8
# 0.014178801486903092
# total step at the end of episode :  4
# 0.013982192752735448
# total step at the end of episode :  4
# 0.011730477455670754
# total step at the end of episode :  6
# 0.013758111578439688
# total step at the end of episode :  4
# 0.01356904038199061
# total step at the end of episode :  4
# 0.01338326056914077
# total step at the end of episode :  4
# 0.014292270005001856
# total step at the end of episode :  16
# 0.013378007217650367
# total step at the end of episode :  4
# 0.01610979702340745
# total step at the end of episode :  10
# 0.016121766810521007
# total step at the end of episode :  6
# 0.014320529881053548
# total step at the end of episode :  8
# 0.0254521648271175
# total step at the end of episode :  8
# 0.013299630965658588
# total step at the end of episode :  4
# 0.013119200933801214
# total step at the end of episode :  4
# 0.017929333080220558
# total step at the end of episode :  8
# 0.021321030152726878
# total step at the end of episode :  10
# 0.013078502909677353
# total step at the end of episode :  4
# 0.016070268102559612
# total step at the end of episode :  10
# 0.012268623300248457
# total step at the end of episode :  16
# 0.014149225334546628
# total step at the end of episode :  14
# 0.013320397743569828
# total step at the end of episode :  4
# 0.011380365110607443
# total step at the end of episode :  6
# 0.01455196582262809
# total step at the end of episode :  16
# 0.013269239921776088
# total step at the end of episode :  4
# 0.00961631678638837
# total step at the end of episode :  10
# 0.019903457910676797
# total step at the end of episode :  8
# 0.011442390727923607
# total step at the end of episode :  6
# 0.011372185617118738
# total step at the end of episode :  6
# 0.011794377762362404
# total step at the end of episode :  8
# 0.021350430600437995
# total step at the end of episode :  10
# 0.013269355718830075
# total step at the end of episode :  4
# 0.018145361754438608
# total step at the end of episode :  8
# 0.015910662223477395
# total step at the end of episode :  10
# 0.013348606469200552
# total step at the end of episode :  4
# 0.0247394691824952
# total step at the end of episode :  10
# 0.017970317935735627
# total step at the end of episode :  8
# 0.013207822608434519
# total step at the end of episode :  4
# 0.017829560347772014
# total step at the end of episode :  40
# 0.013035353768747801
# total step at the end of episode :  4
# 0.012858386979739914
# total step at the end of episode :  4
# 0.013927545343134548
# total step at the end of episode :  14
# 0.011451353523899893
# total step at the end of episode :  8
# 0.012886742496711068
# total step at the end of episode :  4
# 0.012712193631950683
# total step at the end of episode :  4
# 0.010533683554433293
# total step at the end of episode :  8
# 0.011581137114966097
# total step at the end of episode :  16
# 0.02164052814033518
# total step at the end of episode :  12
# 0.012652364014798564
# total step at the end of episode :  6
# 0.01121953600369717
# total step at the end of episode :  6
# 0.01571084605907594
# total step at the end of episode :  20
# 0.012658456891925962
# total step at the end of episode :  4
# 0.01546951498858845
# total step at the end of episode :  6
# 0.012439108842922042
# total step at the end of episode :  4
# 0.01763871075338519
# total step at the end of episode :  8
# 0.012391251612566156
# total step at the end of episode :  4
# 0.012374046213603843
# total step at the end of episode :  8
# 0.012305109226983177
# total step at the end of episode :  8
# 0.012358894145481455
# total step at the end of episode :  4
# 0.011060824310081263
# total step at the end of episode :  6
# 0.012172584381210425
# total step at the end of episode :  4
# 0.01774080522856608
# total step at the end of episode :  8
# 0.011003323398309034
# total step at the end of episode :  6
# 0.01666220321837046
# total step at the end of episode :  12
# 0.012153558442354481
# total step at the end of episode :  4
# 0.015044182445870288
# total step at the end of episode :  6
# 0.011497165910886245
# total step at the end of episode :  12
# 0.01205609142647289
# total step at the end of episode :  4
# 0.011895754253642074
# total step at the end of episode :  4
# 0.013713907988499072
# total step at the end of episode :  8
# 0.010764965699747234
# total step at the end of episode :  6
# 0.011735211691236869
# total step at the end of episode :  4
# 0.01158091854796256
# total step at the end of episode :  4
# 0.011406111729241983
# total step at the end of episode :  8
# 0.013560838276776371
# total step at the end of episode :  14
# 0.009528201936035305
# total step at the end of episode :  10
# 0.010757818457274443
# total step at the end of episode :  6
# 0.017467704417972352
# total step at the end of episode :  8
# 0.014899562909657535
# total step at the end of episode :  6
# 0.015286431396776406
# total step at the end of episode :  10
# 0.016325474862130374
# total step at the end of episode :  12
# 0.012029804715769365
# total step at the end of episode :  4
# 0.011869735843864887
# total step at the end of episode :  4
# 0.016532187921914576
# total step at the end of episode :  12
# 0.011841348453337813
# total step at the end of episode :  4
# 0.019789931509591588
# total step at the end of episode :  10
# 0.011738539459825337
# total step at the end of episode :  4
# 0.012673135071115588
# total step at the end of episode :  14
# 0.01172871321042429
# total step at the end of episode :  4
# 0.010406342870696958
# total step at the end of episode :  6
# 0.011565139920410805
# total step at the end of episode :  4
# 0.011414086835544082
# total step at the end of episode :  4
# 0.011265611457583286
# total step at the end of episode :  4
# 0.011119666126976804
# total step at the end of episode :  4
# 0.010976203845347282
# total step at the end of episode :  4
# 0.012097540384707783
# total step at the end of episode :  6
# 0.01784775869227931
# total step at the end of episode :  12
# 0.010971350871976773
# total step at the end of episode :  4
# 0.01667548353315225
# total step at the end of episode :  8
# 0.018376077419858555
# total step at the end of episode :  6
# 0.017194057895595527
# total step at the end of episode :  14
# 0.010816773217820569
# total step at the end of episode :  4
# 0.01403121490271897
# total step at the end of episode :  10
# 0.010701004877197232
# total step at the end of episode :  4
# 0.010564934645473964
# total step at the end of episode :  4
# 0.01197397437989095
# total step at the end of episode :  10
# 0.012072867548931374
# total step at the end of episode :  6
# 0.010535055473583188
# total step at the end of episode :  4
# 0.018098212687182674
# total step at the end of episode :  6
# 0.009969221672346665
# total step at the end of episode :  6
# 0.013805289977013066
# total step at the end of episode :  6
# 0.010348129772860551
# total step at the end of episode :  4
# 0.009899810475906962
# total step at the end of episode :  6
# 0.010218852501693895
# total step at the end of episode :  4
# 0.010091288293369513
# total step at the end of episode :  4
# 0.009965856006903404
# total step at the end of episode :  4
# 0.014311342149122358
# total step at the end of episode :  10
# 0.02143952593702468
# total step at the end of episode :  10
# 0.012917233769286829
# total step at the end of episode :  8
# 0.01187019938357814
# total step at the end of episode :  6
# 0.009916854964753682
# total step at the end of episode :  6
# 0.012993143934963453
# total step at the end of episode :  14
# 0.010165281395389678
# total step at the end of episode :  4
# 0.011743695676260657
# total step at the end of episode :  6
# 0.010074741534951345
# total step at the end of episode :  4
# 0.009948902541982552
# total step at the end of episode :  4
# 0.009873728157337822
# total step at the end of episode :  8
# 0.0098868650800389
# total step at the end of episode :  8
# 0.009877409771856208
# total step at the end of episode :  4
# 0.011660089864093906
# total step at the end of episode :  6
# 0.009792182324318374
# total step at the end of episode :  4
# 0.0097421873741622
# total step at the end of episode :  6
# 0.009654047689365869
# total step at the end of episode :  4
# 0.011086527389739559
# total step at the end of episode :  12
# 0.009656969359453912
# total step at the end of episode :  6
# 0.01624517260560855
# total step at the end of episode :  8
# 0.017455723286204372
# total step at the end of episode :  6
# 0.009744434326154586
# total step at the end of episode :  4
# 0.017317258972079114
# total step at the end of episode :  6
# 0.009605758855249683
# total step at the end of episode :  4
# 0.011420011081410941
# total step at the end of episode :  6
# 0.010548774977081982
# total step at the end of episode :  22
# 0.009625922665718531
# total step at the end of episode :  4
# 0.011333894294704383
# total step at the end of episode :  12
# 0.011423112712579273
# total step at the end of episode :  6
# 0.009656128471518047
# total step at the end of episode :  4
# 0.009536875219175095
# total step at the end of episode :  4
# 0.009419607824445064
# total step at the end of episode :  4
# 0.009304288188944576
# total step at the end of episode :  4
# 0.009354800917009728
# total step at the end of episode :  6
# 0.010783803440761686
# total step at the end of episode :  8
# 0.016495350714515716
# total step at the end of episode :  8
# 0.009365524033198833
# total step at the end of episode :  4
# 0.012737575050050673
# total step at the end of episode :  6
# 0.009223344584069898
# total step at the end of episode :  4
# 0.015656882915475845
# total step at the end of episode :  12
# 0.00927219601811495
# total step at the end of episode :  4
# 0.009159101002248815
# total step at the end of episode :  4
# 0.011057948010005161
# total step at the end of episode :  6
# 0.009093169517411931
# total step at the end of episode :  4
# 0.01065193886372505
# total step at the end of episode :  10
# 0.009043283487085274
# total step at the end of episode :  4
# 0.009302586548580224
# total step at the end of episode :  6
# 0.008940780807208101
# total step at the end of episode :  4
# 0.00883315498710116
# total step at the end of episode :  4
# 0.008727293313910825
# total step at the end of episode :  4
# 0.00862316184552124
# total step at the end of episode :  4
# 0.0085207272930308
# total step at the end of episode :  4
# 0.012003665155529239
# total step at the end of episode :  6
# 0.015376084712337909
# total step at the end of episode :  8
# 0.015037282342692138
# total step at the end of episode :  12
# 0.016411277306009067
# total step at the end of episode :  6
# 0.009282112580359006
# total step at the end of episode :  8
# 0.008628759913983222
# total step at the end of episode :  4
# 0.00852643493051021
# total step at the end of episode :  4
# 0.012032549176499971
# total step at the end of episode :  6
# 0.01818858650593927
# total step at the end of episode :  10
# 0.01094195205438192
# total step at the end of episode :  6
# 0.01208335087255262
# total step at the end of episode :  6
# 0.014254929505958025
# total step at the end of episode :  10
# 0.008585545612085285
# total step at the end of episode :  4
# 0.011951397649027307
# total step at the end of episode :  20
# 0.009115774074758345
# total step at the end of episode :  6
# 0.015576134556525623
# total step at the end of episode :  8
# 0.008664391402662425
# total step at the end of episode :  4
# 0.010958163591974546
# total step at the end of episode :  6
# 0.008605759601551563
# total step at the end of episode :  4
# 0.008503306332909896
# total step at the end of episode :  4
# 0.016168970804791516
# total step at the end of episode :  6
# 0.011912544567194261
# total step at the end of episode :  6
# 0.009200498388055256
# total step at the end of episode :  6
# 0.009032263334502716
# total step at the end of episode :  6
# 0.011960092945995177
# total step at the end of episode :  6
# 0.008363271227068425
# total step at the end of episode :  4
# 0.015265215720215705
# total step at the end of episode :  8
# 0.010995146962420141
# total step at the end of episode :  6
# 0.008341791513394758
# total step at the end of episode :  4
# 0.011802105495430731
# total step at the end of episode :  6
# 0.008237426809079018
# total step at the end of episode :  4
# 0.00897581833090641
# total step at the end of episode :  6
# 0.008149721013763253
# total step at the end of episode :  4
# 0.00805513466183827
# total step at the end of episode :  4
# 0.011577207661946684
# total step at the end of episode :  6
# 0.007959052052668239
# total step at the end of episode :  4
# 0.007867530824451643
# total step at the end of episode :  4
# 0.007777465225736316
# total step at the end of episode :  4
# 0.0076888272047423295
# total step at the end of episode :  4
# 0.012533558672309666
# total step at the end of episode :  10
# 0.022626490191685153
# total step at the end of episode :  10
# 0.014522811748186107
# total step at the end of episode :  12
# 0.015705736492799327
# total step at the end of episode :  6
# 0.007793068870990405
# total step at the end of episode :  4
# 0.007704621048909774
# total step at the end of episode :  4
# 0.007617562539437642
# total step at the end of episode :  4
# 0.007531866798748343
# total step at the end of episode :  4
# 0.008617754173808057
# total step at the end of episode :  6
# 0.007462233453772241
# total step at the end of episode :  4
# 0.007379056715503429
# total step at the end of episode :  4
# 0.010467994178003592
# total step at the end of episode :  6
# 0.007336888461696167
# total step at the end of episode :  4
# 0.00725541485343445
# total step at the end of episode :  4
# 0.008401827204655252
# total step at the end of episode :  6
# 0.007175150990978249
# total step at the end of episode :  4
# 0.007096267705866535
# total step at the end of episode :  4
# 0.01081551457033697
# total step at the end of episode :  10
# 0.007092064292277822
# total step at the end of episode :  4
# 0.007014576094772143
# total step at the end of episode :  4
# 0.011208024320483831
# total step at the end of episode :  8
# 0.008317185261993487
# total step at the end of episode :  6
# 0.007025908430776634
# total step at the end of episode :  4
# 0.006949608161873996
# total step at the end of episode :  4
# 0.010168836233874101
# total step at the end of episode :  6
# 0.006913013232788437
# total step at the end of episode :  4
# 0.006838205459510957
# total step at the end of episode :  4
# 0.015258222606205504
# total step at the end of episode :  14
# 0.006904027429129461
# total step at the end of episode :  4
# 0.006829258936997484
# total step at the end of episode :  4
# 0.006755617843514569
# total step at the end of episode :  4
# 0.010510489469185383
# total step at the end of episode :  6
# 0.006681725485198797
# total step at the end of episode :  4
# 0.013972798104619655
# total step at the end of episode :  8
# 0.006707400571911479
# total step at the end of episode :  4
# 0.006635307447576025
# total step at the end of episode :  4
# 0.006564297807359065
# total step at the end of episode :  4
# 0.015362072957441297
# total step at the end of episode :  8
# 0.006527203555257155
# total step at the end of episode :  4
# 0.013042592900286129
# total step at the end of episode :  10
# 0.00903669624863078
# total step at the end of episode :  10
# 0.006635670482774525
# total step at the end of episode :  4
# 0.006564640573693117
# total step at the end of episode :  4
# 0.006494675926519838
# total step at the end of episode :  4
# 0.006425756776692257
# total step at the end of episode :  4
# 0.0126433668215358
# total step at the end of episode :  8
# 0.006393897311160551
# total step at the end of episode :  4
# 0.013773460059236547
# total step at the end of episode :  8
# 0.009806440147137607
# total step at the end of episode :  6
# 0.010472628610196835
# total step at the end of episode :  8
# 0.006537095148558131
# total step at the end of episode :  4
# 0.006467008628995963
# total step at the end of episode :  4
# 0.014363229045418577
# total step at the end of episode :  6
# 0.0063952352650568645
# total step at the end of episode :  4
# 0.0063274230307665685
# total step at the end of episode :  4
# 0.0062606236881074945
# total step at the end of episode :  4
# 0.007929195237212111
# total step at the end of episode :  6
# 0.010601841334523535
# total step at the end of episode :  8
# 0.006265367020902524
# total step at the end of episode :  4
# 0.006199698264369266
# total step at the end of episode :  4
# 0.006134998053655624
# total step at the end of episode :  4
# 0.0060712486291047
# total step at the end of episode :  4
# 0.006008432602698621
# total step at the end of episode :  4
# 0.009586069372823025
# total step at the end of episode :  10
# 0.00601394256147901
# total step at the end of episode :  4
# 0.00595205310777977
# total step at the end of episode :  4
# 0.005891061701339559
# total step at the end of episode :  4
# 0.005830952077465229
# total step at the end of episode :  4
# 0.013970641682118548
# total step at the end of episode :  14
# 0.005806453639103287
# total step at the end of episode :  4
# 0.005747533265072671
# total step at the end of episode :  4
# 0.009278681150345483
# total step at the end of episode :  6
# 0.005731843402539419
# total step at the end of episode :  4
# 0.007414682567574035
# total step at the end of episode :  6
# 0.00568219244212799
# total step at the end of episode :  4
# 0.013741611975961021
# total step at the end of episode :  6
# 0.00562658376697342
# total step at the end of episode :  4
# 0.013683830492122226
# total step at the end of episode :  6
# 0.0055738247978806
# total step at the end of episode :  4
# 0.013909101950608765
# total step at the end of episode :  14
# 0.005554074869266318
# total step at the end of episode :  4
# 0.005498826150674346
# total step at the end of episode :  4
# 0.005444356453192661
# total step at the end of episode :  4
# 0.0053906519662484526
# total step at the end of episode :  4
# 0.014572188073827444
# total step at the end of episode :  10
# 0.005366361591978716
# total step at the end of episode :  4
# 0.008961908251641504
# total step at the end of episode :  6
# 0.00535553499798444
# total step at the end of episode :  4
# 0.005302979666363297
# total step at the end of episode :  4
# 0.01265415973767546
# total step at the end of episode :  8
# 0.007387076806889423
# total step at the end of episode :  6
# 0.005363111930549169
# total step at the end of episode :  4
# 0.005310234156737509
# total step at the end of episode :  4
# 0.005258098627609051
# total step at the end of episode :  4
# 0.01371314005082648
# total step at the end of episode :  10
# 0.007359196162830733
# total step at the end of episode :  6
# 0.00943447656049655
# total step at the end of episode :  8
# 0.005367710919600074
# total step at the end of episode :  4
# 0.005314723969754395
# total step at the end of episode :  4
# 0.005262481719255002
# total step at the end of episode :  4
# 0.005210970964904832
# total step at the end of episode :  4
# 0.007278542899099419
# total step at the end of episode :  6
# 0.005182348589556546
# total step at the end of episode :  4
# 0.007832572228473694
# total step at the end of episode :  8
# 0.01396468589128888
# total step at the end of episode :  8
# 0.005181742033326636
# total step at the end of episode :  4
# 0.005131573191714478
# total step at the end of episode :  4
# 0.013351345700473166
# total step at the end of episode :  6
# 0.018299890402520294
# total step at the end of episode :  8
# 0.008757101542797213
# total step at the end of episode :  6
# 0.005169917265494595
# total step at the end of episode :  4
# 0.005119966336048373
# total step at the end of episode :  4
# 0.008672413864421066
# total step at the end of episode :  6
# 0.005075697543903995
# total step at the end of episode :  4
# 0.01324763300800294
# total step at the end of episode :  6
# 0.00503800239926451
# total step at the end of episode :  4
# 0.004989994103571774
# total step at the end of episode :  4
# 0.0049426375435667885
# total step at the end of episode :  4
# 0.004895921510777376
# total step at the end of episode :  4
# 0.004849835023796573
# total step at the end of episode :  4
# 0.004804367323185316
# total step at the end of episode :  4
# 0.0047595078664924295
# total step at the end of episode :  4
# 0.004715246323388642
# total step at the end of episode :  4
# 0.0069603365074287216
# total step at the end of episode :  6
# 0.004693888422882167
# total step at the end of episode :  4
# 0.0046505412879913055
# ...
# 0.00011566739453088178
# total step at the end of episode :  4
# 0.00011545680166453152
# total step at the end of episode :  4
# 0.00011524681975065738
# total step at the end of episode :  4
# 0.00011503744631947109
# total step at the end of episode :  4
# 0.00011482867891293713
# total step at the end of episode :  4
# 0.0001146205150866185
# total step at the end of episode :  4
# 0.00011441295240705203
# total step at the end of episode :  4
# 0.00011420598845577473
# total step at the end of episode :  4
# 0.00011399962082493664
# total step at the end of episode :  4
# 0.00011379384711985956
# total step at the end of episode :  4
# 0.001541727926483303
# total step at the end of episode :  6
# 0.00011692730542553487
# total step at the end of episode :  4
# 0.0001167111703210301
# total step at the end of episode :  4
# 0.0001164956746624729
# total step at the end of episode :  4
# 0.00011628081580594349
# total step at the end of episode :  4
# 0.00011606659112324558
# total step at the end of episode :  4
# 0.00011585299799823576
# total step at the end of episode :  4
# 0.00011564003383022527
# total step at the end of episode :  4
# 0.00011542769603257487
# total step at the end of episode :  4
# 0.00011521598203089248
# total step at the end of episode :  4
# 0.00011500488926532645
# total step at the end of episode :  4
# 0.00011479441518974509
# total step at the end of episode :  4
# 0.00011458455727071833
# total step at the end of episode :  4
# 0.00011437531298931145
# total step at the end of episode :  4
# 0.00011416667983859576
# total step at the end of episode :  4
# 0.00011395865532577015
# total step at the end of episode :  4
# 0.00011375123697038997
# total step at the end of episode :  4
# 0.00011354442230600108
# total step at the end of episode :  4
# 0.00011333820887857692
# total step at the end of episode :  4
# 0.00011313259424596336
# total step at the end of episode :  4
# 0.00011292757598032298
# total step at the end of episode :  4
# 0.00011272315166630832
# total step at the end of episode :  4
# 0.00011251931890044961
# total step at the end of episode :  4
# 0.00011231607529206544
# total step at the end of episode :  4
# 0.00011211341846315177
# total step at the end of episode :  4
# 0.001543686957483928
# total step at the end of episode :  6
# 0.00011527331360065493
# total step at the end of episode :  4
# 0.00011506017055973664
# total step at the end of episode :  4
# 0.00011484766050573122
# total step at the end of episode :  4
# 0.00011463578080753677
# total step at the end of episode :  4
# 0.00011442452884831943
# total step at the end of episode :  4
# 0.0008762110316871425
# total step at the end of episode :  6
# 0.0001150749949643641
# total step at the end of episode :  4
# 0.00011486356849443359
# total step at the end of episode :  4
# 0.00011465276474870688
# total step at the end of episode :  4
# 0.00011444258116394095
# total step at the end of episode :  4
# 0.00011423301518624293
# total step at the end of episode :  4
# 0.0001140240642780576
# total step at the end of episode :  4
# 0.00011381572591309674
# total step at the end of episode :  4
# 0.0011092643341569196
# total step at the end of episode :  6
# 0.0001151291821241407
# total step at the end of episode :  4
# 0.00011491851855222057
# total step at the end of episode :  4
# 0.00011470847082521371
# total step at the end of episode :  4
# 0.00011449903643149205
# total step at the end of episode :  4
# 0.00011429021287065813
# total step at the end of episode :  4
# 0.00011408199765821324
# total step at the end of episode :  4
# 0.00011387438832035843
# total step at the end of episode :  4
# 0.0001136673823970702
# total step at the end of episode :  4
# 0.00011346097744120015
# total step at the end of episode :  4
# 0.00011325517101864503
# total step at the end of episode :  4
# 0.00011304996070785577
# total step at the end of episode :  4
# 0.0001128453440989649
# total step at the end of episode :  4
# 0.00011264131879667669
# total step at the end of episode :  4
# 0.00011243788241583307
# total step at the end of episode :  4
# 0.00011223503258551634
# total step at the end of episode :  4
# 0.00011203276694602381
# total step at the end of episode :  4
# 0.0001118310831503648
# total step at the end of episode :  4
# 0.00011162997886400745
# total step at the end of episode :  4
# 0.0001114294517626721
# total step at the end of episode :  4
# 0.00011122949953699945
# total step at the end of episode :  4
# 0.00011103011988677393
# total step at the end of episode :  4
# 0.00011083131052600469
# total step at the end of episode :  4
# 0.00011063306917834595
# total step at the end of episode :  4
# 0.00011043539358074513
# total step at the end of episode :  4
# 0.0001102382814807297
# total step at the end of episode :  4
# 0.00011004173063785747
# total step at the end of episode :  4
# 0.00010984573882314233
# total step at the end of episode :  4
# 0.00010965030381911503
# total step at the end of episode :  4
# 0.00010945542341894189
# total step at the end of episode :  4
# 0.00010926109542884303
# total step at the end of episode :  4
# 0.00010906731766283789
# total step at the end of episode :  4
# 0.00010887408795067811
# total step at the end of episode :  4
# 0.00010868140412847484
# total step at the end of episode :  4
# 0.00010848926404757354
# total step at the end of episode :  4
# 0.0011092821092757513
# total step at the end of episode :  6
# 0.00010984488384685118
# total step at the end of episode :  4
# 0.00010965018355249198
# total step at the end of episode :  4
# 0.00010945603187265465
# total step at the end of episode :  4
# 0.00010926242665753802
# total step at the end of episode :  4
# 0.0001090693657665575
# total step at the end of episode :  4
# 0.00010887684707210077
# total step at the end of episode :  4
# 0.00010868486845584148
# total step at the end of episode :  4
# 0.00010849342781055551
# total step at the end of episode :  4
# 0.00010830252303873321
# total step at the end of episode :  4
# 0.00010811215205605573
# total step at the end of episode :  4
# 0.00010792231278456549
# total step at the end of episode :  4
# 0.0001077330031610986
# total step at the end of episode :  4
# 0.00010754422112855926
# total step at the end of episode :  4
# 0.00010735596464346749
# total step at the end of episode :  4
# 0.00010716823167113837
# total step at the end of episode :  4
# 0.00010698102018631694
# total step at the end of episode :  4
# 0.00010679432817532232
# total step at the end of episode :  4
# 0.00010660815363328774
# total step at the end of episode :  4
# 0.00010642249456614683
# total step at the end of episode :  4
# 0.00010623734898971594
# total step at the end of episode :  4
# 0.00010605271492799412
# total step at the end of episode :  4
# 0.0001058685904173854
# total step at the end of episode :  4
# 0.00010568497350141662
# total step at the end of episode :  4
# 0.00010550186223534479
# total step at the end of episode :  4
# 0.00010531925468327402
# total step at the end of episode :  4
# 0.0001051371489178797
# total step at the end of episode :  4
# 0.0011168157950019204
# total step at the end of episode :  6
# 0.00010654541589365414
# total step at the end of episode :  4
# 0.0014706312027645673
# total step at the end of episode :  6
# 0.00010937722661059392
# total step at the end of episode :  4
# 0.00010918291052457868
# total step at the end of episode :  4
# 0.00010898914356228216
# total step at the end of episode :  4
# 0.00010879592356864091
# total step at the end of episode :  4
# 0.00010860324839418508
# total step at the end of episode :  4
# 0.00010841111590538782
# total step at the end of episode :  4
# 0.00010821952397646432
# total step at the end of episode :  4
# 0.0001080284704920607
# total step at the end of episode :  4
# 0.00010783795334955073
# total step at the end of episode :  4
# 0.00010764797045542066
# total step at the end of episode :  4
# 0.00010745851972691813
# total step at the end of episode :  4
# 0.0001072695990914016
# total step at the end of episode :  4
# 0.0001070812064880829
# total step at the end of episode :  4
# 0.00010689333986407812
# total step at the end of episode :  4
# 0.00439105186667493
# total step at the end of episode :  6
# 0.00010725604409414589
# total step at the end of episode :  4
# 0.00010706855362400177
# total step at the end of episode :  4
# 0.00010688158373448487
# total step at the end of episode :  4
# 0.00010669513241612014
# total step at the end of episode :  4
# 0.0001065091976699007
# total step at the end of episode :  4
# 0.00010632377750543348
# total step at the end of episode :  4
# 0.0008487995431285195
# total step at the end of episode :  6
# 0.00010695866261092174
# total step at the end of episode :  4
# 0.00010677292911619347
# total step at the end of episode :  4
# 0.00010658770694327649
# total step at the end of episode :  4
# 0.00010640299413446942
# total step at the end of episode :  4
# 0.00010621878874543869
# total step at the end of episode :  4
# 0.00010603508883873236
# total step at the end of episode :  4
# 0.00010585189248861916
# total step at the end of episode :  4
# 0.00010566919777615143
# total step at the end of episode :  4
# 0.00010548700279422799
# total step at the end of episode :  4
# 0.00010530530564330752
# total step at the end of episode :  4
# 0.00010512410443432301
# total step at the end of episode :  4
# 0.00010494339728717248
# total step at the end of episode :  4
# 0.00010476318233061492
# total step at the end of episode :  4
# 0.0008616894033310202
# total step at the end of episode :  6
# 0.00010544122107946155
# total step at the end of episode :  4
# 0.00010526054300655403
# total step at the end of episode :  4
# 0.00010508035457312478
# total step at the end of episode :  4
# 0.00010490065393763126
# total step at the end of episode :  4
# 0.0001047214392677371
# total step at the end of episode :  4
# 0.00010454270873889657
# total step at the end of episode :  4
# 0.00010436446053656637
# total step at the end of episode :  4
# 0.00010418669285420026
# total step at the end of episode :  4
# 0.00010400940389359258
# total step at the end of episode :  4
# 0.00010383259186659902
# total step at the end of episode :  4
# 0.00010365625499213563
# total step at the end of episode :  4
# 0.00010348039149811472
# total step at the end of episode :  4
# 0.00010330499962231746
# total step at the end of episode :  4
# 0.00010313007760819233
# total step at the end of episode :  4
# 0.00010295562371115223
# total step at the end of episode :  4
# 0.00010278163619127298
# total step at the end of episode :  4
# 0.00010260811331916884
# total step at the end of episode :  4
# 0.00010243505337348413
# total step at the end of episode :  4
# 0.0001022624546409192
# total step at the end of episode :  4
# 0.00010209031541536222
# total step at the end of episode :  4
# 0.0011011083940557671
# total step at the end of episode :  6
# 0.00010346593609198221
# total step at the end of episode :  4
# 0.0001032910611717527
# total step at the end of episode :  4
# 0.00010311665204474577
# total step at the end of episode :  4
# 0.00010294270699434845
# total step at the end of episode :  4
# 0.00010276922431201076
# total step at the end of episode :  4
# 0.0001025962022957929
# total step at the end of episode :  4
# 0.0001024236392556041
# total step at the end of episode :  4
# 0.0008671631970863193
# total step at the end of episode :  6
# 0.00010313173444669553
# total step at the end of episode :  4
# 0.00010295857546342539
# total step at the end of episode :  4
# 0.00010278587368969284
# total step at the end of episode :  4
# 0.00010261362745618043
# total step at the end of episode :  4
# 0.0001024418351019147
# total step at the end of episode :  4
# 0.00010227049497364346
# total step at the end of episode :  4
# 0.00010209960542619662
# total step at the end of episode :  4
# 0.00010192916482082946
# total step at the end of episode :  4
# 0.00010175917152802257
# total step at the end of episode :  4
# 0.0001015896239250462
# total step at the end of episode :  4
# 0.0008413657460923322
# total step at the end of episode :  6
# 0.00010229204523796998
# total step at the end of episode :  4
# 0.00010212187110803655
# total step at the end of episode :  4
# 0.00010195214119324177
# total step at the end of episode :  4
# 0.00010178285388957181
# total step at the end of episode :  4
# 0.0001016140076046234
# total step at the end of episode :  4
# 0.00010144560075317499
# total step at the end of episode :  4
# 0.00010127763175364103
# total step at the end of episode :  4
# 0.00010111009903586779
# total step at the end of episode :  4
# 0.00010094300103531684
# total step at the end of episode :  4
# 0.00010077633619382832
# total step at the end of episode :  4
# 0.0001006101029610209
# total step at the end of episode :  4
# 0.00010044429979490233
# total step at the end of episode :  4
# 0.0001002789251584521
# total step at the end of episode :  4
# 0.00010011397752272486
# total step at the end of episode :  4
# 0.0011059550428292111
# total step at the end of episode :  6
# 0.00010151871823068509
# total step at the end of episode :  4
# 0.0001013508861401162
# total step at the end of episode :  4
# 0.00010118348824266973
# total step at the end of episode :  4
# 0.00010101652298934692
# total step at the end of episode :  4
# 0.00010084998884130059
# total step at the end of episode :  4
# 0.00010068388426620264
# total step at the end of episode :  4
# 0.00010051820773627693
# total step at the end of episode :  4
# 0.00010035295773429612
# total step at the end of episode :  4
# 0.0001001881327476993
# total step at the end of episode :  4
# 0.00010002373127102754
# total step at the end of episode :  4
# 0.0011284228611276922
# total step at the end of episode :  6
# 0.00010150895451225064
# total step at the end of episode :  4
# 0.00010134137193473433
# total step at the end of episode :  4
# 0.00010117422136707993
# total step at the end of episode :  4
# 0.00010100750128038717
# total step at the end of episode :  4
# 0.00010084121015194701
# total step at the end of episode :  4
# 0.0001006753464639909
# total step at the end of episode :  4
# 0.00010050990870835372
# total step at the end of episode :  4
# 0.0013675549652855407
# total step at the end of episode :  6
# 0.00010291118583988408
# total step at the end of episode :  4
# 0.0001027387975534328
# total step at the end of episode :  4
# 0.00010256686202164515
# total step at the end of episode :  4
# 0.00010239537760465059
# total step at the end of episode :  4
# 0.00010222434267383347
# total step at the end of episode :  4
# 0.0001020537556045073
# total step at the end of episode :  4
# 0.0001018836147808587
# total step at the end of episode :  4
# 0.00010171391859432714
# total step at the end of episode :  4
# 0.00010154466544473086
# total step at the end of episode :  4
# 0.00010137585373821804
# total step at the end of episode :  4
# 0.00010120748188770581
# total step at the end of episode :  4
# 0.001391102249169279
# total step at the end of episode :  6
# 0.00010371038111202033
# total step at the end of episode :  4
# 0.00010353461154254465
# total step at the end of episode :  4
# 0.00010335931096417186
# total step at the end of episode :  4
# 0.00010318447764689175
# total step at the end of episode :  4
# 0.00010301010987114577
# total step at the end of episode :  4
# 0.00010283620592331684
# total step at the end of episode :  4
# 0.00010266276409797923
# total step at the end of episode :  4
# 0.00010248978269994206
# total step at the end of episode :  4
# 0.00010231726003829579
# total step at the end of episode :  4
# 0.00010214519443397727
# total step at the end of episode :  4
# 0.00010197358421299395
# total step at the end of episode :  4
# 0.00010180242771005987
# total step at the end of episode :  4
# 0.00010163172326841524
# total step at the end of episode :  4
# 0.00010146146923858176
# total step at the end of episode :  4
# 0.00010129166397783353
# total step at the end of episode :  4
# 0.00010112230585292148
# total step at the end of episode :  4
# 0.00010095339323604093
# total step at the end of episode :  4
# 0.00010078492451016247
# total step at the end of episode :  4
# 0.00010061689806169574
# total step at the end of episode :  4
# 0.00010044931228781698
# total step at the end of episode :  4
# 0.004328422452983958
# total step at the end of episode :  6
# 0.00010080630272405085
# total step at the end of episode :  4
# 0.00010063895531863248
# total step at the end of episode :  4
# 0.00010047204457554453
# total step at the end of episode :  4
# 0.00010030556892205549
# total step at the end of episode :  4
# 0.0001001395267895373
# total step at the end of episode :  4
# 9.997391661978501e-05
# total step at the end of episode :  4
